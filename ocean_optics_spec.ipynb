# %%
# %pip install numpy matplotlib astropy ipywidgets seabreeze pyusb
#mac may need: brew install libusb
# %pip install "ipywidgets==7.7.1" widgetsnbextension
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipywidgets as widgets, numpy as np, matplotlib.pyplot as plt
# %matplotlib inline

def f(x):
    plt.figure()
    xs = np.linspace(0, 10, 500)
    plt.plot(xs, np.sin(xs * x))
    plt.show()

widgets.interact(f, x=widgets.FloatSlider(min=0.1, max=5, step=0.1, value=1))
# Out:
# interactive(children=(FloatSlider(value=1.0, description='x', max=5.0, min=0.1), Output()), _dom_classes=('wid…
# <function __main__.f(x)>

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import astropy
from astropy import units as u
from astropy.table import Table
# %matplotlib inline

from ipywidgets import interactive
from matplotlib.widgets import Slider, Button, RadioButtons

# %%
from seabreeze.spectrometers import Spectrometer
spec=Spectrometer.from_first_available()
# Out:
# ---------------------------------------------------------------------------
# SeaBreezeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 from seabreeze.spectrometers import Spectrometer
# ----> 2 spec=Spectrometer.from_first_available()
#
# File ~/.venvs/mono/lib/python3.13/site-packages/seabreeze/spectrometers.py:152, in Spectrometer.from_first_available(cls)
#     150         return cls(dev)
#     151 else:
# --> 152     raise cls._backend.SeaBreezeError("No unopened device found.")
#
# SeaBreezeError: No unopened device found.

# %%
def specplot(wavemin=0,wavemax=1000,exptime=1):
    plt.figure(figsize=(10,10))
    spec.integration_time_micros(1e6*exptime)
    spint=spec.intensities()
    spwave=spec.wavelengths()
    p=np.where((spwave>wavemin) & (spwave<wavemax))
    plt.plot(spwave[p[0]],spint[p[0]])
    plt.show()

# %%
# %pip install --upgrade ipywidgets
import ipywidgets as w
print("ipywidgets:", w.__version__)
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ipywidgets: 8.1.8

# %%
import ipywidgets as widgets
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def f(x):
    plt.figure()
    xs = np.linspace(0, 10, 500)
    plt.plot(xs, np.sin(xs * x))
    plt.show()

widgets.interact(f, x=widgets.FloatSlider(min=0.1, max=5, step=0.1, value=1))
# Out:
# interactive(children=(FloatSlider(value=1.0, description='x', max=5.0, min=0.1), Output()), _dom_classes=('wid…
# <function __main__.f(x)>

# %%
interactive_plot = interactive(specplot, wavemin=(0, 1000, 1),wavemax=(0,1000,1),exptime=(0,1,.01))
interactive_plot
# Out:
# interactive(children=(IntSlider(value=0, description='wavemin', max=1000), IntSlider(value=1000, description='…
